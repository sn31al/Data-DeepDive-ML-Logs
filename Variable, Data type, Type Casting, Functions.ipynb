# %% [markdown]
# Variables & Data Types  -- 15 & 16

# %%
import keyword
print(keyword.kwlist)
# Out:
# ['False', 'None', 'True', 'and', 'as', 'assert', 'async', 'await', 'break', 'class', 'continue', 'def', 'del', 'elif', 'else', 'except', 'finally', 'for', 'from', 'global', 'if', 'import', 'in', 'is', 'lambda', 'nonlocal', 'not', 'or', 'pass', 'raise', 'return', 'try', 'while', 'with', 'yield']

# %%
len(keyword.kwlist)
# Out:
# 35

# %% [markdown]
# # Differrent Data Types:
# int ----->Numeric------->42  ||
# float------>Numeric------>3.14  ||
# complex-------->Numeric------>1 + 5j  ||
# bool--------->Boolean-------->True or False  ||
# str----------->"Text (Often treated as simple, though technically a sequence of characters)"--------->"""hello"""   ||

# %%
Vn = 10
Vn #int
# Out:
# 10

# %%
flt = 2.5
flt #float
# Out:
# 2.5

# %%
strng = 'hello'
strng #string
# Out:
# 'hello'

# %%
active = True
active #bool
# Out:
# True

# %%
c = 10+20j
c
# Out:
# (10+20j)

# %%
c.real, c.imag
# Out:
# (10.0, 20.0)

# %%
d = 20+30j
print(c+d)
print(c-d)
print(c*d)
# Out:
# (30+50j)
# (-10-10j)
# (-400+700j)

# %%
a = 2.4
b =5.7
print(a+b)
# Out:
# 8.1

# %%
percent = 70
percent
# Out:
# 70

# %% [markdown]
# String Concatenation

# %%
fn = 'Gudio'
mn = 'Van'
ln = 'Russom'
print(fn+mn,ln)
flln = fn+" "+mn+" "+ln
flln
# Out:
# GudioVan Russom
# 'Gudio Van Russom'

# %%
print(flln)
# Out:
# Gudio Van Russom

# %%
type(flln)
# Out:
# str

# %%
print(type(percent))
# Out:
# <class 'int'>

# %%
# Variables with new assigned values

first_name = "ANIL"
last_name = "KUMAR"
country = "USA"
city = "NEW YORK"
age = 29
is_married = False
skills = ["Java", "SQL", "Spring Boot", "AWS", "Docker"]
person_info = {
    "firstname": "John",
    "lastname": "Doe",
    "country": "Canada",
    "city": "Toronto",
}

# --- Printing the new values stored in the variables ---

print("First name:", first_name)
print("First name length:", len(first_name))
print("Last name: ", last_name)
print("Last name length: ", len(last_name))
print("Country: ", country)
print("City: ", city)
print("Age: ", age)
print("Married: ", is_married)
print("Skills: ", skills)
print("Person information: ", person_info)
# Out:
# First name: ANIL
# First name length: 4
# Last name:  KUMAR
# Last name length:  5
# Country:  USA
# City:  NEW YORK
# Age:  29
# Married:  False
# Skills:  ['Java', 'SQL', 'Spring Boot', 'AWS', 'Docker']
# Person information:  {'firstname': 'John', 'lastname': 'Doe', 'country': 'Canada', 'city': 'Toronto'}

# %%
first_name, last_name, country, age, is_married = ( "Durga", "Prasad", "Osaka", 250, True)
print(first_name, last_name, country, age, is_married)
# Out:
# Durga Prasad Osaka 250 True

# %%
print(type(age), type(first_name), type(is_married))
# Out:
# <class 'int'> <class 'str'> <class 'bool'>

# %%
import sys
sys.version
# Out:
# '3.13.7 | packaged by Anaconda, Inc. | (main, Sep  9 2025, 19:54:37) [MSC v.1929 64 bit (AMD64)]'

# %% [markdown]
# python variable = identifier = object

# %% [markdown]
# syntax ( variable = value)

# %%
v@=16
v@ # Dont Use Special Variables
# Out:
#   Cell In[20], line 2
#     v@ # Dont Use Special Variables
#        ^
# SyntaxError: invalid syntax

# %%
a_ = 10
a_
# Out:
# 10

# %%
1var = 45
1var
# Out:
#   Cell In[22], line 1
#     1var = 45
#     ^
# SyntaxError: invalid decimal literal

# %%
def = 10 # Not Valid as def is used to define an user defined fucntion
# Out:
#   Cell In[23], line 1
#     def = 10 # Not Valid as def is used to define an user defined fucntion
#         ^
# SyntaxError: invalid syntax

# %%
DEF = 10
DEF
# Out:
# 10

# %%
false = 10
false
# Out:
# 10

# %%
False = 10 # Not Valid as they are keywords
# Out:
#   Cell In[26], line 1
#     False = 10 # Not Valid as they are keywords
#     ^
# SyntaxError: cannot assign to False

# %%
s = 'hello'
s
# Out:
# 'hello'

# %%
s1 = "hello"
s1
# Out:
# 'hello'

# %%
s2 = ''' hello '''
s2
# Out:
# ' hello '

# %%
s3 = '''Hi 
            Guys'''
s3
# Out:
# 'Hi \n            Guys'

# %%
print(3 ** 2)  # exponential(**  -- square)
print(6 % 2)   # modulus(%)  -- remainder
print(6 // 2)  # Floor division operator(//)  -- quotient
# Out:
# 9
# 0
# 3

# %% [markdown]
# # Type Casting  == Convert one Dataype to Other Dataype

# %% [markdown]
# All other data types to Int

# %%
int(2.4)
# Out:
# 2

# %%
int(True)
# Out:
# 1

# %%
int(true) #just variable is not considered
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[34], line 1
# ----> 1 int(true) #just variable is not considered
#
# NameError: name 'true' is not defined

# %%
int (True, False) # Can't take more than two arguments
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[36], line 1
# ----> 1 int (True, False) # Can't take more than two arguments
#
# TypeError: int() can't convert non-string with explicit base

# %%
int('10') # number based string can be converted
# Out:
# 10

# %%
int('ten') #text based string can't be converted
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[38], line 1
# ----> 1 int('ten') #text based string can't be converted
#
# ValueError: invalid literal for int() with base 10: 'ten'

# %%
int(20+3j) # can't convert to complex
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[39], line 1
# ----> 1 int(20+3j) # can't convert to complex
#
# TypeError: int() argument must be a string, a bytes-like object or a real number, not 'complex'

# %% [markdown]
# All other data types to float

# %%
float(20000)
# Out:
# 20000.0

# %%
float(2,3) #can't take more than two arguments
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[41], line 1
# ----> 1 float(2,3) #can't take more than two arguments
#
# TypeError: float expected at most 1 argument, got 2

# %%
float(True)
# Out:
# 1.0

# %%
float(False)
# Out:
# 0.0

# %%
float('10')
# Out:
# 10.0

# %%
float('ten') # text based string can't be converted
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[45], line 1
# ----> 1 float('ten') # text based string can't be converted
#
# ValueError: could not convert string to float: 'ten'

# %%
float(10+20j)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[46], line 1
# ----> 1 float(10+20j)
#
# TypeError: float() argument must be a string or a real number, not 'complex'

# %%
f = 1e0
f
# Out:
# 1.0

# %%
f1 = 2e1
f1
# Out:
# 20.0

# %%
f2 = 2.4e2
f2
# Out:
# 240.0

# %%
f3 = 2.5e3
f3
# Out:
# 2500.0

# %%
type(f3)
# Out:
# float

# %% [markdown]
# All other data types to string

# %%
str(48)
# Out:
# '48'

# %%
str('48')
# Out:
# '48'

# %%
str(4.8)
# Out:
# '4.8'

# %%
str(10+20j)
# Out:
# '(10+20j)'

# %%
str(True)
# Out:
# 'True'

# %%
str(True,False) #cant take two arguments
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[57], line 1
# ----> 1 str(True,False) #cant take two arguments
#
# TypeError: str() argument 'encoding' must be str, not bool

# %%
str(False)
# Out:
# 'False'

# %% [markdown]
# All other data types to boolean

# %%
bool(10)
# Out:
# True

# %%
bool(2.3)
# Out:
# True

# %%
bool(0)
# Out:
# False

# %%
bool()
# Out:
# False

# %%
bool(10+20j)
# Out:
# True

# %%
bool('10')
# Out:
# True

# %%
bool('ten')
# Out:
# True

# %% [markdown]
# All other data types to complex

# %%
complex(10)
# Out:
# (10+0j)

# %%
complex(10.20,30)
# Out:
# (10.2+30j)

# %%
complex(False)
# Out:
# 0j

# %%
complex(True)
# Out:
# (1+0j)

# %%
complex('10')
# Out:
# (10+0j)

# %%
complex(True,False)
# Out:
# (1+0j)

# %%
complex('ten') # can't take text based string as arg
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[72], line 1
# ----> 1 complex('ten') # can't take text based string as arg
#
# ValueError: complex() arg is a malformed string

# %%
complex(10,20,30) #only 2 args needed given 3 args
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[73], line 1
# ----> 1 complex(10,20,30) #only 2 args needed given 3 args
#
# TypeError: complex() takes at most 2 arguments (3 given)

# %%
complex('10', '20') #two string arg are not considered
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[74], line 1
# ----> 1 complex('10', '20') #two string arg are not considered
#
# TypeError: complex() can't take second arg if first is a string

# %% [markdown]
# # String Functions and Indexing and slicing and other

# %%
i = 12
i
id(i)
# Out:
# 140711978509576

# %%
j = 12
q = 12
print(id(i),id(j),id(q))
'''if(id(i) == id(j) == id(q)):
    print("Memory allocated at the same loction, pointers pointing to same location but different variables")
else:
    print("Something went wrong!!")'''
# Out:
# 140711978509576 140711978509576 140711978509576
# 'if(id(i) == id(j) == id(q)):\n    print("Memory allocated at the same loction, pointers pointing to same location but different variables")\nelse:\n    print("Something went wrong!!")'

# %%
q=30

# %%
id(q)
# Out:
# 140711978510152

# %%
str = 'Statistics'
str
# Out:
# 'Statistics'

# %%
str[0]
# Out:
# 'S'

# %%
str[1]
# Out:
# 't'

# %%
str[0:11]
# Out:
# 'Statistics'

# %%
print(str[-10])
print(str[-9])
print(str[-8])
print(str[-7])
print(str[-6])
print(str[-5])
print(str[-4])
print(str[-3])
print(str[-2])
print(str[-1])
# Out:
# S
# t
# a
# t
# i
# s
# t
# i
# c
# s

# %%
str
# Out:
# 'Statistics'

# %%
len(str)
# Out:
# 10

# %%
str[3:11]
# Out:
# 'tistics'

# %%
str[0:6]
# Out:
# 'Statis'

# %%
str[0:11:2]
# Out:
# 'Saitc'

# %%
str[0:11:4]
# Out:
# 'Sic'

# %%
str[:8:2]
# Out:
# 'Sait'

# %%
str[0::4]
# Out:
# 'Sic'

# %%
str[::3]
# Out:
# 'Stts'

# %%
str[:]
# Out:
# 'Statistics'

# %%
print(s,str)
# Out:
# hello Statistics

# %%
print(s + str)
# Out:
# helloStatistics

# %% [markdown]
# # Operators

# %% [raw]
# # TYPES OF OPERATORS:
# 1. Arithmatic Operator
# 2. Assignment Operator
# 3. Relational Operator
# 4. logical Operator
# 5. Unary Operator

# %%
a = 15
b = 4
print(f"a + b (Addition): {a + b}")           
print(f"a - b (Subtraction): {a - b}")        
print(f"a * b (Multiplication): {a * b}")     
print(f"a / b (Division): {a / b}")         
print(f"a // b (Floor Division): {a // b}") 
print(f"a % b (Modulus/Remainder): {a % b}")  
print(f"a ** 2 (Exponentiation): {a ** 2}")
# Out:
# a + b (Addition): 19
# a - b (Subtraction): 11
# a * b (Multiplication): 60
# a / b (Division): 3.75
# a // b (Floor Division): 3
# a % b (Modulus/Remainder): 3
# a ** 2 (Exponentiation): 225

# %%
x = 10
print(f"Initial x: {x}")
x += 5  
print(f"x after x += 5: {x}")   
x -= 2  
print(f"x after x -= 2: {x}")   
x *= 3  
print(f"x after x *= 3: {x}")   
x /= 13 
print(f"x after x /= 13: {x}")
# Out:
# Initial x: 10
# x after x += 5: 15
# x after x -= 2: 13
# x after x *= 3: 39
# x after x /= 13: 3.0

# %%
print(f"a == b (Equal to): {a == b}")       
print(f"a != b (Not equal to): {a != b}")   
print(f"a > b (Greater than): {a > b}")     
print(f"a < b (Less than): {a < b}")         
print(f"a >= b (Greater than or equal to): {a >= b}")
print(f"a <= 15 (Less than or equal to): {a <= 15}")
# Out:
# a == b (Equal to): False
# a != b (Not equal to): True
# a > b (Greater than): True
# a < b (Less than): False
# a >= b (Greater than or equal to): True
# a <= 15 (Less than or equal to): True

# %%
p = True
q = False
print(f"p is {p}, q is {q}")
print(f"p and q (AND): {p and q}") 
print(f"p or q (OR): {p or q}")    
print(f"not p (NOT): {not p}")
# Out:
# p is True, q is False
# p and q (AND): False
# p or q (OR): True
# not p (NOT): False

# %%
y = 7
z = -10
print(f"Initial y: {y}")
print(f"Initial z: {z}")
# Unary Plus: Returns the value unchanged 
print(f"+y (Unary Plus): {+y}")  # 7
# Unary Minus: Negates the value
print(f"-y (Unary Minus): {-y}")  # -7
# Unary Minus can flip a negative to a positive
print(f"-z (Negation of -10): {-z}")
# Out:
# Initial y: 7
# Initial z: -10
# +y (Unary Plus): 7
# -y (Unary Minus): -7
# -z (Negation of -10): 10

# %%
# The complement operator (~) is applied to an integer.
number = 5
complement_result = ~number
# complement formula: -(number + 1)
print(f"Original number: {number}")
print(f"Complement (~) result: {complement_result}") 
print(f"Check with formula: {-(number + 1)}") 
negative_number = -10
print(f"Original number: {negative_number}")
print(f"Complement (~) result: {~negative_number}")
# Out:
# Original number: 5
# Complement (~) result: -6
# Check with formula: -6
# Original number: -10
# Complement (~) result: 9

# %%
bin(number)
# Out:
# '0b101'

# %%
20
bin(20)
# Out:
# '0b10100'

# %%
50
bin(50)
# Out:
# '0b110010'

# %%
# Octal
number1 = 5
number2 = 20
number3 = 50
number4 = 64
number5 = 0o55
print(f"Decimal 5:   {oct(number1)}")  
print(f"Decimal 20:  {oct(number2)}") 
print(f"Decimal 50:  {oct(number3)}") 
print(f"Decimal 64:  {oct(number4)}") 
print(f"Decimal num5: {number5}")
# Out:
# Decimal 5:   0o5
# Decimal 20:  0o24
# Decimal 50:  0o62
# Decimal 64:  0o100
# Decimal num5: 45
